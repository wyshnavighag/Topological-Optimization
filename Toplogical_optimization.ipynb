# %%
pip install calfem-python
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: calfem-python in /usr/local/lib/python3.7/site-packages (3.6.3)
# Requirement already satisfied: pyvtk in /usr/local/lib/python3.7/site-packages (from calfem-python) (0.5.18)
# Requirement already satisfied: visvis in /usr/local/lib/python3.7/site-packages (from calfem-python) (1.13.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/site-packages (from calfem-python) (1.21.6)
# Requirement already satisfied: vedo in /usr/local/lib/python3.7/site-packages (from calfem-python) (2022.4.1)
# Requirement already satisfied: qtpy in /usr/local/lib/python3.7/site-packages (from calfem-python) (2.3.0)
# Requirement already satisfied: gmsh in /usr/local/lib/python3.7/site-packages (from calfem-python) (4.11.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.7/site-packages (from calfem-python) (3.5.3)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.7/site-packages (from calfem-python) (0.9.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/site-packages (from calfem-python) (1.7.3)
# Requirement already satisfied: six in /usr/local/lib/python3.7/site-packages (from pyvtk->calfem-python) (1.14.0)
# Requirement already satisfied: pyOpenGl in /usr/local/lib/python3.7/site-packages (from visvis->calfem-python) (3.1.6)
# Requirement already satisfied: vtk in /usr/local/lib/python3.7/site-packages (from vedo->calfem-python) (9.2.2)
# Requirement already satisfied: Deprecated in /usr/local/lib/python3.7/site-packages (from vedo->calfem-python) (1.2.13)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/site-packages (from qtpy->calfem-python) (21.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.7/site-packages (from matplotlib->calfem-python) (2.8.2)
# Requirement already satisfied: pyparsing>=2.2.1 in /usr/local/lib/python3.7/site-packages (from matplotlib->calfem-python) (3.0.9)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.7/site-packages (from matplotlib->calfem-python) (4.38.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.7/site-packages (from matplotlib->calfem-python) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.7/site-packages (from matplotlib->calfem-python) (1.4.4)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.7/site-packages (from matplotlib->calfem-python) (9.3.0)
# Requirement already satisfied: wslink>=1.0.4 in /usr/local/lib/python3.7/site-packages (from vtk->vedo->calfem-python) (1.9.1)
# Requirement already satisfied: wrapt<2,>=1.10 in /usr/local/lib/python3.7/site-packages (from Deprecated->vedo->calfem-python) (1.14.1)
# Requirement already satisfied: typing-extensions; python_version < "3.8" in /usr/local/lib/python3.7/site-packages (from kiwisolver>=1.0.1->matplotlib->calfem-python) (4.4.0)
# Requirement already satisfied: aiohttp<4 in /usr/local/lib/python3.7/site-packages (from wslink>=1.0.4->vtk->vedo->calfem-python) (3.8.3)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in /usr/local/lib/python3.7/site-packages (from aiohttp<4->wslink>=1.0.4->vtk->vedo->calfem-python) (2.1.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.7/site-packages (from aiohttp<4->wslink>=1.0.4->vtk->vedo->calfem-python) (4.0.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.7/site-packages (from aiohttp<4->wslink>=1.0.4->vtk->vedo->calfem-python) (1.8.1)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.7/site-packages (from aiohttp<4->wslink>=1.0.4->vtk->vedo->calfem-python) (1.3.1)
# Requirement already satisfied: asynctest==0.13.0; python_version < "3.8" in /usr/local/lib/python3.7/site-packages (from aiohttp<4->wslink>=1.0.4->vtk->vedo->calfem-python) (0.13.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.7/site-packages (from aiohttp<4->wslink>=1.0.4->vtk->vedo->calfem-python) (6.0.2)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.7/site-packages (from aiohttp<4->wslink>=1.0.4->vtk->vedo->calfem-python) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.7/site-packages (from aiohttp<4->wslink>=1.0.4->vtk->vedo->calfem-python) (22.1.0)
# Requirement already satisfied: idna>=2.0 in /usr/local/lib/python3.7/site-packages (from yarl<2.0,>=1.0->aiohttp<4->wslink>=1.0.4->vtk->vedo->calfem-python) (2.8)

# %%
pip install pyopt
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: pyopt in /usr/local/lib/python3.7/site-packages (0.84)

# %%
pip install visvis
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: visvis in /usr/local/lib/python3.7/site-packages (1.13.0)
# Requirement already satisfied: pyOpenGl in /usr/local/lib/python3.7/site-packages (from visvis) (3.1.6)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/site-packages (from visvis) (1.21.6)

# %%
pip install pyvtk
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: pyvtk in /usr/local/lib/python3.7/site-packages (0.5.18)
# Requirement already satisfied: six in /usr/local/lib/python3.7/site-packages (from pyvtk) (1.14.0)

# %%
pip install sphinx==1.6.6
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: sphinx==1.6.6 in /usr/local/lib/python3.7/site-packages (1.6.6)
# Requirement already satisfied: Pygments>=2.0 in /usr/local/lib/python3.7/site-packages (from sphinx==1.6.6) (2.13.0)
# Requirement already satisfied: docutils>=0.11 in /usr/local/lib/python3.7/site-packages (from sphinx==1.6.6) (0.19)
# Requirement already satisfied: snowballstemmer>=1.1 in /usr/local/lib/python3.7/site-packages (from sphinx==1.6.6) (2.2.0)
# Requirement already satisfied: requests>=2.0.0 in /usr/local/lib/python3.7/site-packages (from sphinx==1.6.6) (2.22.0)
# Requirement already satisfied: Jinja2>=2.3 in /usr/local/lib/python3.7/site-packages (from sphinx==1.6.6) (3.1.2)
# Requirement already satisfied: babel!=2.0,>=1.3 in /usr/local/lib/python3.7/site-packages (from sphinx==1.6.6) (2.11.0)
# Requirement already satisfied: imagesize in /usr/local/lib/python3.7/site-packages (from sphinx==1.6.6) (1.4.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/site-packages (from sphinx==1.6.6) (1.14.0)
# Requirement already satisfied: alabaster<0.8,>=0.7 in /usr/local/lib/python3.7/site-packages (from sphinx==1.6.6) (0.7.12)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/site-packages (from sphinx==1.6.6) (45.2.0.post20200210)
# Requirement already satisfied: sphinxcontrib-websupport in /usr/local/lib/python3.7/site-packages (from sphinx==1.6.6) (1.2.4)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.7/site-packages (from requests>=2.0.0->sphinx==1.6.6) (3.0.4)
# Requirement already satisfied: idna<2.9,>=2.5 in /usr/local/lib/python3.7/site-packages (from requests>=2.0.0->sphinx==1.6.6) (2.8)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/site-packages (from requests>=2.0.0->sphinx==1.6.6) (2019.11.28)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/site-packages (from requests>=2.0.0->sphinx==1.6.6) (1.25.8)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.7/site-packages (from Jinja2>=2.3->sphinx==1.6.6) (2.1.1)
# Requirement already satisfied: pytz>=2015.7 in /usr/local/lib/python3.7/site-packages (from babel!=2.0,>=1.3->sphinx==1.6.6) (2022.6)
# Requirement already satisfied: sphinxcontrib-serializinghtml in /usr/local/lib/python3.7/site-packages (from sphinxcontrib-websupport->sphinx==1.6.6) (1.1.5)

# %%
pip install git+https://github.com/ErikSaterskog/PyTOpt.git --user
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting git+https://github.com/ErikSaterskog/PyTOpt.git
#   Cloning https://github.com/ErikSaterskog/PyTOpt.git to /tmp/pip-req-build-q0z7f8sh
#   Running command git clone -q https://github.com/ErikSaterskog/PyTOpt.git /tmp/pip-req-build-q0z7f8sh
# Requirement already satisfied (use --upgrade to upgrade): PyTOpt==1.0.1 from git+https://github.com/ErikSaterskog/PyTOpt.git in /root/.local/lib/python3.7/site-packages
# Requirement already satisfied: visvis in /usr/local/lib/python3.7/site-packages (from PyTOpt==1.0.1) (1.13.0)
# Requirement already satisfied: pyvtk in /usr/local/lib/python3.7/site-packages (from PyTOpt==1.0.1) (0.5.18)
# Requirement already satisfied: calfem-python in /usr/local/lib/python3.7/site-packages (from PyTOpt==1.0.1) (3.6.3)
# Requirement already satisfied: sphinx==1.6.6 in /usr/local/lib/python3.7/site-packages (from PyTOpt==1.0.1) (1.6.6)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/site-packages (from PyTOpt==1.0.1) (1.7.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/site-packages (from PyTOpt==1.0.1) (1.21.6)
# Requirement already satisfied: pyOpenGl in /usr/local/lib/python3.7/site-packages (from visvis->PyTOpt==1.0.1) (3.1.6)
# Requirement already satisfied: six in /usr/local/lib/python3.7/site-packages (from pyvtk->PyTOpt==1.0.1) (1.14.0)
# Requirement already satisfied: gmsh in /usr/local/lib/python3.7/site-packages (from calfem-python->PyTOpt==1.0.1) (4.11.0)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.7/site-packages (from calfem-python->PyTOpt==1.0.1) (0.9.0)
# Requirement already satisfied: qtpy in /usr/local/lib/python3.7/site-packages (from calfem-python->PyTOpt==1.0.1) (2.3.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.7/site-packages (from calfem-python->PyTOpt==1.0.1) (3.5.3)
# Requirement already satisfied: vedo in /usr/local/lib/python3.7/site-packages (from calfem-python->PyTOpt==1.0.1) (2022.4.1)
# Requirement already satisfied: snowballstemmer>=1.1 in /usr/local/lib/python3.7/site-packages (from sphinx==1.6.6->PyTOpt==1.0.1) (2.2.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/site-packages (from sphinx==1.6.6->PyTOpt==1.0.1) (45.2.0.post20200210)
# Requirement already satisfied: babel!=2.0,>=1.3 in /usr/local/lib/python3.7/site-packages (from sphinx==1.6.6->PyTOpt==1.0.1) (2.11.0)
# Requirement already satisfied: alabaster<0.8,>=0.7 in /usr/local/lib/python3.7/site-packages (from sphinx==1.6.6->PyTOpt==1.0.1) (0.7.12)
# Requirement already satisfied: imagesize in /usr/local/lib/python3.7/site-packages (from sphinx==1.6.6->PyTOpt==1.0.1) (1.4.1)
# Requirement already satisfied: Pygments>=2.0 in /usr/local/lib/python3.7/site-packages (from sphinx==1.6.6->PyTOpt==1.0.1) (2.13.0)
# Requirement already satisfied: docutils>=0.11 in /usr/local/lib/python3.7/site-packages (from sphinx==1.6.6->PyTOpt==1.0.1) (0.19)
# Requirement already satisfied: Jinja2>=2.3 in /usr/local/lib/python3.7/site-packages (from sphinx==1.6.6->PyTOpt==1.0.1) (3.1.2)
# Requirement already satisfied: requests>=2.0.0 in /usr/local/lib/python3.7/site-packages (from sphinx==1.6.6->PyTOpt==1.0.1) (2.22.0)
# Requirement already satisfied: sphinxcontrib-websupport in /usr/local/lib/python3.7/site-packages (from sphinx==1.6.6->PyTOpt==1.0.1) (1.2.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/site-packages (from qtpy->calfem-python->PyTOpt==1.0.1) (21.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.7/site-packages (from matplotlib->calfem-python->PyTOpt==1.0.1) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.7/site-packages (from matplotlib->calfem-python->PyTOpt==1.0.1) (1.4.4)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.7/site-packages (from matplotlib->calfem-python->PyTOpt==1.0.1) (0.11.0)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.7/site-packages (from matplotlib->calfem-python->PyTOpt==1.0.1) (9.3.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.7/site-packages (from matplotlib->calfem-python->PyTOpt==1.0.1) (4.38.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /usr/local/lib/python3.7/site-packages (from matplotlib->calfem-python->PyTOpt==1.0.1) (3.0.9)
# Requirement already satisfied: Deprecated in /usr/local/lib/python3.7/site-packages (from vedo->calfem-python->PyTOpt==1.0.1) (1.2.13)
# Requirement already satisfied: vtk in /usr/local/lib/python3.7/site-packages (from vedo->calfem-python->PyTOpt==1.0.1) (9.2.2)
# Requirement already satisfied: pytz>=2015.7 in /usr/local/lib/python3.7/site-packages (from babel!=2.0,>=1.3->sphinx==1.6.6->PyTOpt==1.0.1) (2022.6)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.7/site-packages (from Jinja2>=2.3->sphinx==1.6.6->PyTOpt==1.0.1) (2.1.1)
# Requirement already satisfied: idna<2.9,>=2.5 in /usr/local/lib/python3.7/site-packages (from requests>=2.0.0->sphinx==1.6.6->PyTOpt==1.0.1) (2.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/site-packages (from requests>=2.0.0->sphinx==1.6.6->PyTOpt==1.0.1) (1.25.8)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/site-packages (from requests>=2.0.0->sphinx==1.6.6->PyTOpt==1.0.1) (2019.11.28)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.7/site-packages (from requests>=2.0.0->sphinx==1.6.6->PyTOpt==1.0.1) (3.0.4)
# Requirement already satisfied: sphinxcontrib-serializinghtml in /usr/local/lib/python3.7/site-packages (from sphinxcontrib-websupport->sphinx==1.6.6->PyTOpt==1.0.1) (1.1.5)
# Requirement already satisfied: typing-extensions; python_version < "3.8" in /usr/local/lib/python3.7/site-packages (from kiwisolver>=1.0.1->matplotlib->calfem-python->PyTOpt==1.0.1) (4.4.0)
# Requirement already satisfied: wrapt<2,>=1.10 in /usr/local/lib/python3.7/site-packages (from Deprecated->vedo->calfem-python->PyTOpt==1.0.1) (1.14.1)
# Requirement already satisfied: wslink>=1.0.4 in /usr/local/lib/python3.7/site-packages (from vtk->vedo->calfem-python->PyTOpt==1.0.1) (1.9.1)
# Requirement already satisfied: aiohttp<4 in /usr/local/lib/python3.7/site-packages (from wslink>=1.0.4->vtk->vedo->calfem-python->PyTOpt==1.0.1) (3.8.3)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in /usr/local/lib/python3.7/site-packages (from aiohttp<4->wslink>=1.0.4->vtk->vedo->calfem-python->PyTOpt==1.0.1) (2.1.1)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.7/site-packages (from aiohttp<4->wslink>=1.0.4->vtk->vedo->calfem-python->PyTOpt==1.0.1) (1.3.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.7/site-packages (from aiohttp<4->wslink>=1.0.4->vtk->vedo->calfem-python->PyTOpt==1.0.1) (1.2.0)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.7/site-packages (from aiohttp<4->wslink>=1.0.4->vtk->vedo->calfem-python->PyTOpt==1.0.1) (4.0.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.7/site-packages (from aiohttp<4->wslink>=1.0.4->vtk->vedo->calfem-python->PyTOpt==1.0.1) (22.1.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.7/site-packages (from aiohttp<4->wslink>=1.0.4->vtk->vedo->calfem-python->PyTOpt==1.0.1) (6.0.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.7/site-packages (from aiohttp<4->wslink>=1.0.4->vtk->vedo->calfem-python->PyTOpt==1.0.1) (1.8.1)
# Requirement already satisfied: asynctest==0.13.0; python_version < "3.8" in /usr/local/lib/python3.7/site-packages (from aiohttp<4->wslink>=1.0.4->vtk->vedo->calfem-python->PyTOpt==1.0.1) (0.13.0)
# Building wheels for collected packages: PyTOpt
#   Building wheel for PyTOpt (setup.py) ... done
#   Created wheel for PyTOpt: filename=PyTOpt-1.0.1-py3-none-any.whl size=39237 sha256=8363d242fe88496ca6a8a00fb483efdd2b5a522782565cecc47dc9f0f1e2c673
#   Stored in directory: /tmp/pip-ephem-wheel-cache-at3b4hav/wheels/fe/e3/a7/22e831042871e991b3f5ec329c290f925c63a9989e36f5d923
# Successfully built PyTOpt

# %%
# !git clone https://github.com/ErikSaterskog/PyTOpt.git
# Out:
# fatal: destination path 'PyTOpt' already exists and is not an empty directory.

# %%
# !python setup.py install
# Out:
# python: can't open file 'setup.py': [Errno 2] No such file or directory

# %%
import calfem.geometry as cfg
import as PyTOpt
from Pytopt import Material_Routine_Selection as mrs
from Pytopt import Object_Func_Selection as ofs
from Pytopt import Optimisation as opt

# %%
# Creating geometry

g = cfg.Geometry()

g.point([0,0])                 
g.point([1,0])                
g.point([1,0.5],marker=9)      
g.point([0.5,0.5])              
g.point([0.5,1])              
g.point([0,1])                

g.line([0, 1])
g.line([1, 2])
g.line([2, 3])
g.line([3, 4])
g.line([4, 5],marker=4)
g.line([5, 0])

g.surface([0, 1, 2, 3,4,5])

# %%
# Forces and boundary conditions
force = [-1e7,9,2]                                  
bmarker = 4                                         
eq =[0,0]

# %%
# Material parameters
mp = {'E':210e9,'nu':0.3,'eps_y':0 }                
materialFun = mrs.Bilinear

# %%
# Settings, Objective function and Optimisation routine
ep=[1,True,2]
settings = {'volFrac':0.3,'meshSize':0.08,'rmin':0.08*0.7,'changeLimit': 0.01,'SIMP_const':3}
ObjectFun = ofs.Compliance
OptFun = opt.OC

# %%
# Calling the optimisation
PyTOpt.Main(g, force, bmarker, mp, ep, materialFun, ObjectFun, OptFun,settings,eq)
# Out:
# Info    : GMSH -> Python-module
# Initializing...
# Number of elements: 340
# H:0.014873190999423969
# G0:         789105.283198613
# Change:     0.10000000000000003
# Opt.Iters:  1
# ---------------------------------
# G0:         501081.7662313679
# Change:     0.10000000000000003
# Opt.Iters:  2
# ---------------------------------
# G0:         364522.5123889723
# Change:     0.10000000000000003
# Opt.Iters:  3
# ---------------------------------
# G0:         281390.44421432924
# Change:     0.10000000000000003
# Opt.Iters:  4
# ---------------------------------
# G0:         221818.61881947465
# Change:     0.10000000000000003
# Opt.Iters:  5
# ---------------------------------
# G0:         177816.51838775014
# Change:     0.10000000000000003
# Opt.Iters:  6
# ---------------------------------
# G0:         144102.13009390113
# Change:     0.1
# Opt.Iters:  7
# ---------------------------------
# G0:         119341.22064728275
# Change:     0.1
# Opt.Iters:  8
# ---------------------------------
# G0:         103283.00772750223
# Change:     0.0988025324257421
# Opt.Iters:  9
# ---------------------------------
# G0:         92753.58282926603
# Change:     0.07652737962712008
# Opt.Iters:  10
# ---------------------------------
# G0:         85877.61225134063
# Change:     0.07480208989648124
# Opt.Iters:  11
# ---------------------------------
# G0:         81877.84505725422
# Change:     0.06315597058437852
# Opt.Iters:  12
# ---------------------------------
# G0:         79130.03191921108
# Change:     0.050308172848155086
# Opt.Iters:  13
# ---------------------------------
# G0:         77496.11087183827
# Change:     0.04817991924271181
# Opt.Iters:  14
# ---------------------------------
# G0:         76247.87165127047
# Change:     0.047383009446381574
# Opt.Iters:  15
# ---------------------------------
# G0:         75532.66462751613
# Change:     0.04107229224765829
# Opt.Iters:  16
# ---------------------------------
# G0:         74860.05909716371
# Change:     0.035624962732749954
# Opt.Iters:  17
# ---------------------------------
# G0:         74434.66745241245
# Change:     0.03611391818438903
# Opt.Iters:  18
# ---------------------------------
# G0:         73950.63688180351
# Change:     0.03253422771550596
# Opt.Iters:  19
# ---------------------------------
# G0:         73609.80864117449
# Change:     0.04233162364155274
# Opt.Iters:  20
# ---------------------------------
# G0:         73170.39526430269
# Change:     0.04133956514568754
# Opt.Iters:  21
# ---------------------------------
# G0:         72827.81038320171
# Change:     0.050107944439112984
# Opt.Iters:  22
# ---------------------------------
# G0:         72380.1035981827
# Change:     0.04476584937703082
# Opt.Iters:  23
# ---------------------------------
# G0:         72021.97049216073
# Change:     0.04480888656825205
# Opt.Iters:  24
# ---------------------------------
# G0:         71593.13148524478
# Change:     0.049441485684031394
# Opt.Iters:  25
# ---------------------------------
# G0:         71271.64832324571
# Change:     0.05272703351036723
# Opt.Iters:  26
# ---------------------------------
# G0:         70920.95556114797
# Change:     0.06574552040667614
# Opt.Iters:  27
# ---------------------------------
# G0:         70683.84526660558
# Change:     0.05445190356275775
# Opt.Iters:  28
# ---------------------------------
# G0:         70481.70820611462
# Change:     0.03588754726844273
# Opt.Iters:  29
# ---------------------------------
# G0:         70413.66573991218
# Change:     0.02873880632617498
# Opt.Iters:  30
# ---------------------------------
# Total computation time: 0m 11.0s
# Final G0: 70413.66573991218
# ---------------------------------
# [789105.283198613, 501081.7662313679, 364522.5123889723, 281390.44421432924, 221818.61881947465, 177816.51838775014, 144102.13009390113, 119341.22064728275, 103283.00772750223, 92753.58282926603, 85877.61225134063, 81877.84505725422, 79130.03191921108, 77496.11087183827, 76247.87165127047, 75532.66462751613, 74860.05909716371, 74434.66745241245, 73950.63688180351, 73609.80864117449, 73170.39526430269, 72827.81038320171, 72380.1035981827, 72021.97049216073, 71593.13148524478, 71271.64832324571, 70920.95556114797, 70683.84526660558, 70481.70820611462, 70413.66573991218]
# N.iters:    1
# Final error:1.3115668892805305e-06
# Max eps_h:  0.0015018876171019417
# Min eps_h:  -0.0014102272048436522
